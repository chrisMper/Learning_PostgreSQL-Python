# %% [markdown]
# # Connecting to PostgreSQL
# First, we need to install the required libraries if you haven't already. You can run this in your terminal:
# `pip install psycopg2-binary pandas`

# %% [markdown]
# for the postgreSQL driver run the following code.

# %%
# !python -m pip install sqlalchemy psycopg2-binary pandas
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 949.4 kB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.1 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.2 MB/s eta 0:00:02
# ...

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# Connet postgreSQL with python

# %%
USERNAME = "postgres"
PASSWORD = "admin"
HOST = "localhost"
PORT = "5432"
DB_NAME = "store_performance_db"

engine = create_engine(f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}")

# %% [markdown]
# Test the connection

# %%
with engine.connect() as conn:
 result = conn.execute(text("SELECT version();"))
 print(result.fetchone())
# Out:
# ('PostgreSQL 18.4 on x86_64-windows, compiled by msvc-19.44.35226, 64-bit',)
